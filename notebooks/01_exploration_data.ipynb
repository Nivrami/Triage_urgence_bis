# %% [markdown]
# # 1. Exploration des données
#
# Ce notebook explore les datasets disponibles pour le projet.

# %%
# Imports
import pandas as pd
from datasets import load_dataset

# %% [markdown]
# ## 1.1 Dataset medical-cases-fr

# %%
# Charger le dataset
# dataset = load_dataset('mlabonne/medical-cases-fr')
# df = pd.DataFrame(dataset['train'])
# df.head()

# %% [markdown]
# ## 1.2 Catégories de gravité
#
# Analyser les catégories GRIS, VERT, JAUNE, ROUGE

# %%
# TODO: Charger et analyser les catégories
